# %% [markdown]
# # Description

# %% [markdown]
# It takes GLS PhenoPLIER results on a random phenotype and verifies that the QQ-plots look fine (without inflation).

# %% [markdown]
# # Modules

# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
library(qqman)
# Out:
# For example usage please run: vignette('qqman')
#
#
#
# Citation appreciated but not required:
#
# Turner, (2018). qqman: an R package for visualizing GWAS results using Q-Q and manhattan plots. Journal of Open Source Software, 3(25), 731, https://doi.org/10.21105/joss.00731.

# %% [markdown]
# # Paths

# %%
GLS_NULL_SIMS_DIR <- Sys.getenv("PHENOPLIER_RESULTS_GLS_NULL_SIMS")

# %%
GLS_NULL_SIMS_DIR
# Out:
# [1] "/home/miltondp/projects/phenoplier/clean_orig_base/phenoplier-gwas-40pcs/results/gls/null_sims"

# %%
GLS_PHENOPLIER_DIR <- file.path(GLS_NULL_SIMS_DIR, "phenoplier", "ukbb_eur", "covars", "gls-gtex_v8_mashr-sub_corr")

# %%
GLS_PHENOPLIER_DIR
# Out:
# [1] "/home/miltondp/projects/phenoplier/clean_orig_base/phenoplier-gwas-40pcs/results/gls/null_sims/phenoplier/ukbb_eur/covars/gls-gtex_v8_mashr-sub_corr"

# %% [markdown]
# # Random pheno 0

# %%
pheno_code <- "0"

# %% [markdown]
# ## Load data

# %%
gls_ph <- as.data.frame(read_tsv(file.path(GLS_PHENOPLIER_DIR, paste0("random.pheno", pheno_code,"-gls_phenoplier.tsv.gz"))))
# Out:
# Rows: 987 Columns: 6
# ── Column specification ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (1): lv
# dbl (5): beta, beta_se, t, pvalue_twosided, pvalue_onesided
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
dim(gls_ph)
# Out:
# [1] 987   6

# %%
head(gls_ph)
# Out:
#   lv    beta      beta_se   t        pvalue_twosided pvalue_onesided
# 1 LV8   0.5785641 0.1248130 4.635447 3.631854e-06    1.815927e-06
# 2 LV618 0.5499133 0.1255366 4.380502 1.202821e-05    6.014107e-06
# 3 LV701 0.5058563 0.1257707 4.022053 5.835249e-05    2.917624e-05
# 4 LV160 0.3910182 0.1250466 3.126981 1.773979e-03    8.869895e-04
# 5 LV568 0.3895208 0.1267065 3.074198 2.119522e-03    1.059761e-03
# 6 LV960 0.3681592 0.1253748 2.936470 3.331457e-03    1.665728e-03

# %% [markdown]
# ### QQ-plot

# %%
options(repr.plot.width = 10, repr.plot.height = 10)

qq(
    gls_ph$pvalue_onesided,
    main = paste0("random pheno ", pheno_code, " - QQ plot of GLS PhenoPLIER")
)
# Out:
# Plot with title “random pheno 0 - QQ plot of GLS PhenoPLIER”

# %% [markdown]
# # Random pheno 1

# %%
pheno_code <- "1"

# %% [markdown]
# ## Load data

# %%
gls_ph <- as.data.frame(read_tsv(file.path(GLS_PHENOPLIER_DIR, paste0("random.pheno", pheno_code,"-gls_phenoplier.tsv.gz"))))
# Out:
# Rows: 987 Columns: 6
# ── Column specification ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (1): lv
# dbl (5): beta, beta_se, t, pvalue_twosided, pvalue_onesided
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
dim(gls_ph)
# Out:
# [1] 987   6

# %%
head(gls_ph)
# Out:
#   lv    beta      beta_se   t        pvalue_twosided pvalue_onesided
# 1 LV189 0.4915319 0.1349121 3.643350 0.0002712289    0.0001356144
# 2 LV108 0.4227407 0.1256164 3.365331 0.0007689862    0.0003844931
# 3 LV548 0.4040546 0.1248993 3.235044 0.0012223796    0.0006111898
# 4 LV275 0.3771040 0.1247991 3.021688 0.0025235657    0.0012617829
# 5 LV43  0.3582854 0.1254905 2.855079 0.0043163586    0.0021581793
# 6 LV919 0.3491175 0.1262430 2.765440 0.0057007943    0.0028503971

# %% [markdown]
# ### QQ-plot

# %%
options(repr.plot.width = 10, repr.plot.height = 10)

qq(
    gls_ph$pvalue_onesided,
    main = paste0("random pheno ", pheno_code, " - QQ plot of GLS PhenoPLIER")
)
# Out:
# Plot with title “random pheno 1 - QQ plot of GLS PhenoPLIER”

# %% [markdown]
# # Random pheno 2

# %%
pheno_code <- "2"

# %% [markdown]
# ## Load data

# %%
gls_ph <- as.data.frame(read_tsv(file.path(GLS_PHENOPLIER_DIR, paste0("random.pheno", pheno_code,"-gls_phenoplier.tsv.gz"))))
# Out:
# Rows: 987 Columns: 6
# ── Column specification ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (1): lv
# dbl (5): beta, beta_se, t, pvalue_twosided, pvalue_onesided
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
dim(gls_ph)
# Out:
# [1] 987   6

# %%
head(gls_ph)
# Out:
#   lv    beta      beta_se   t        pvalue_twosided pvalue_onesided
# 1 LV208 0.3795004 0.1250473 3.034855 0.002416120     0.001208060
# 2 LV136 0.3430760 0.1259447 2.724022 0.006466617     0.003233309
# 3 LV664 0.3388376 0.1261945 2.685044 0.007270601     0.003635300
# 4 LV946 0.3276706 0.1252369 2.616406 0.008906821     0.004453410
# 5 LV54  0.3240589 0.1262266 2.567278 0.010272400     0.005136200
# 6 LV765 0.3173289 0.1294164 2.451999 0.014232838     0.007116419

# %% [markdown]
# ### QQ-plot

# %%
options(repr.plot.width = 10, repr.plot.height = 10)

qq(
    gls_ph$pvalue_onesided,
    main = paste0("random pheno ", pheno_code, " - QQ plot of GLS PhenoPLIER")
)
# Out:
# Plot with title “random pheno 2 - QQ plot of GLS PhenoPLIER”

# %% [markdown]
# # Random pheno 3

# %%
pheno_code <- "3"

# %% [markdown]
# ## Load data

# %%
gls_ph <- as.data.frame(read_tsv(file.path(GLS_PHENOPLIER_DIR, paste0("random.pheno", pheno_code,"-gls_phenoplier.tsv.gz"))))
# Out:
# Rows: 987 Columns: 6
# ── Column specification ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (1): lv
# dbl (5): beta, beta_se, t, pvalue_twosided, pvalue_onesided
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
dim(gls_ph)
# Out:
# [1] 987   6

# %%
head(gls_ph)
# Out:
#   lv    beta      beta_se   t        pvalue_twosided pvalue_onesided
# 1 LV826 0.4220614 0.1249872 3.376838 0.0007375830    0.0003687915
# 2 LV674 0.4204021 0.1251443 3.359337 0.0007858329    0.0003929165
# 3 LV687 0.3793951 0.1253562 3.026536 0.0024835087    0.0012417544
# 4 LV944 0.3757168 0.1263694 2.973162 0.0029583968    0.0014791984
# 5 LV780 0.3615849 0.1247726 2.897952 0.0037687488    0.0018843744
# 6 LV45  0.4045029 0.1412879 2.862970 0.0042104515    0.0021052258

# %% [markdown]
# ### QQ-plot

# %%
options(repr.plot.width = 10, repr.plot.height = 10)

qq(
    gls_ph$pvalue_onesided,
    main = paste0("random pheno ", pheno_code, " - QQ plot of GLS PhenoPLIER")
)
# Out:
# Plot with title “random pheno 3 - QQ plot of GLS PhenoPLIER”

# %% [markdown]
# # Random pheno 4

# %%
pheno_code <- "4"

# %% [markdown]
# ## Load data

# %%
gls_ph <- as.data.frame(read_tsv(file.path(GLS_PHENOPLIER_DIR, paste0("random.pheno", pheno_code,"-gls_phenoplier.tsv.gz"))))
# Out:
# Rows: 987 Columns: 6
# ── Column specification ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (1): lv
# dbl (5): beta, beta_se, t, pvalue_twosided, pvalue_onesided
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
dim(gls_ph)
# Out:
# [1] 987   6

# %%
head(gls_ph)
# Out:
#   lv    beta      beta_se   t        pvalue_twosided pvalue_onesided
# 1 LV937 0.5920742 0.1254120 4.721034 2.396117e-06    1.198059e-06
# 2 LV407 0.3983537 0.1254894 3.174401 1.508529e-03    7.542643e-04
# 3 LV582 0.3754774 0.1256878 2.987380 2.824393e-03    1.412197e-03
# 4 LV720 0.3696558 0.1250085 2.957045 3.117302e-03    1.558651e-03
# 5 LV144 0.3581334 0.1251118 2.862506 4.216612e-03    2.108306e-03
# 6 LV425 0.3568462 0.1258269 2.836008 4.582369e-03    2.291184e-03

# %% [markdown]
# ### QQ-plot

# %%
options(repr.plot.width = 10, repr.plot.height = 10)

qq(
    gls_ph$pvalue_onesided,
    main = paste0("random pheno ", pheno_code, " - QQ plot of GLS PhenoPLIER")
)
# Out:
# Plot with title “random pheno 4 - QQ plot of GLS PhenoPLIER”
